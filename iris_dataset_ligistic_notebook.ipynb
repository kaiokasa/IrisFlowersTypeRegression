# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
os.getcwd()
# Out:
# 'c:\\Users\\hamoud\\Desktop\\Iris_dataset'

# %%
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["target"] = iris.target_names[iris.target]
df.to_csv("iris_dataset.csv", index=False)

# %%
df.to_csv("iris_dataset.csv", index=False)
df["target"].value_counts()
# Out:
# target
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X = df[["petal width (cm)"]]
y = df["target"] == 'virginica'
y
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: target, Length: 150, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42,stratify=y)
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
X_new = np.linspace(0, 3, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)
decision_boundary = X_new[y_proba[:, 1] >= 0.5][0, 0]
# Out:
# c:\Users\hamoud\miniconda3\envs\torch-nightly\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.plot(X_new, y_proba[:, 0], "b--", linewidth=2,
label="Not Iris virginica proba")
plt.plot(X_new, y_proba[:, 1], "g-", linewidth=2, 
label="Iris virginica proba")
plt.plot([decision_boundary, decision_boundary], [0, 1], 
"k:", linewidth=2,
label="Decision boundary")
plt.show()

# %%
decision_boundary
# Out:
# np.float64(1.6666666666666667)

# %%
log_reg.predict([[1.7], [1.5]])
# Out:
# c:\Users\hamoud\miniconda3\envs\torch-nightly\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([ True, False])
